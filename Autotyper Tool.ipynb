# %%
# autotype testing

# %%
# v6 ENTER

import time
import csv
import keyboard  # Importing keyboard library
from pynput import keyboard as kb_listener

# CSV file to read
csv_file = 'C:/Users/JoelTencer/Documents/autotype_enter.csv'

# Global variable to track if the Escape key is pressed
escape_pressed = False

# Define listener to terminate script on Escape key press
def on_press(key):
    global escape_pressed
    if key == kb_listener.Key.esc:
        escape_pressed = True
        return False  # Stop the listener

# Start the keyboard listener
listener = kb_listener.Listener(on_press=on_press)
listener.start()

# Delay for ten seconds to switch to the desired window
time.sleep(10)

# Print don't close Window
print("Don't close this window until typing is finished")

# Print Press Esc to cancel
print("Press Esc to stop automatic typing")

# Open and read the CSV file with explicit encoding
with open(csv_file, 'r', encoding='utf-8-sig') as file:
    reader = csv.reader(file)
    for row in reader:
        if len(row) < 3:
            print("Skipping row: Not enough columns")
            continue
        
        # Read columns
        first_column = row[0].strip()
        second_column = row[1].strip()
        third_column = row[2].strip()
        
        # Build the text to type with conditional spaces
        parts = []
        if first_column:
            parts.append(first_column)
        if second_column:
            parts.append(second_column)
        if third_column:
            parts.append(third_column)
        
        text_to_type = ' '.join(parts)
        
        # Check if the Escape key is pressed
        if escape_pressed:
            print("Escape key pressed. Exiting...")
            break
        
        # Type the line of text using the keyboard library
        keyboard.write(text_to_type)

        # Press the enter key to simulate typing
        keyboard.press_and_release('enter')

        # Delay for a short interval between each line
        # time.sleep(2)

# Stop the keyboard listener
listener.stop()
# Out:
# Don't close this window until typing is finished
# Press Esc to stop automatic typing

# %%
# v6 DOWN

import time
import csv
import keyboard  # Importing keyboard library
from pynput import keyboard as kb_listener

# CSV file to read
csv_file = 'C:/Users/JoelTencer/Documents/autotype_down.csv'

# Global variable to track if the Escape key is pressed
escape_pressed = False

# Define listener to terminate script on Escape key press
def on_press(key):
    global escape_pressed
    if key == kb_listener.Key.esc:
        escape_pressed = True
        return False  # Stop the listener

# Start the keyboard listener
listener = kb_listener.Listener(on_press=on_press)
listener.start()

# Delay for ten seconds to switch to the desired window
time.sleep(10)

# Print don't close Window
print("Don't close this window until typing is finished")

# Print Press Esc to cancel
print("Press Esc to stop automatic typing")

# Open and read the CSV file with explicit encoding
with open(csv_file, 'r', encoding='utf-8-sig') as file:
    reader = csv.reader(file)
    for row in reader:
        if len(row) < 3:
            print("Skipping row: Not enough columns")
            continue
        
        # Read columns
        first_column = row[0].strip()
        second_column = row[1].strip()
        third_column = row[2].strip()
        
        # Build the text to type with conditional spaces
        parts = []
        if first_column:
            parts.append(first_column)
        if second_column:
            parts.append(second_column)
        if third_column:
            parts.append(third_column)
        
        text_to_type = ' '.join(parts)
        
        # Check if the Escape key is pressed
        if escape_pressed:
            print("Escape key pressed. Exiting...")
            break
        
        # Type the line of text using the keyboard library
        keyboard.write(text_to_type)

        # Press the Down key to simulate typing
        keyboard.press_and_release('down')

        # Delay for a short interval between each line
        # time.sleep(2)

# Stop the keyboard listener
listener.stop()
# Out:
# Don't close this window until typing is finished
# Press Esc to stop automatic typing

# %%
# v5 DOWN

import time
import csv
import keyboard  # Importing keyboard library
from pynput import keyboard as kb_listener

# CSV file to read
csv_file = 'C:/Users/JoelTencer/Documents/autotype_down.csv'

# Global variable to track if the Escape key is pressed
escape_pressed = False

# Define listener to terminate script on Escape key press
def on_press(key):
    global escape_pressed
    if key == kb_listener.Key.esc:
        escape_pressed = True
        return False  # Stop the listener

# Start the keyboard listener
listener = kb_listener.Listener(on_press=on_press)
listener.start()

# Delay for ten seconds to switch to the desired window
time.sleep(10)

# Print don't close Window
print("Don't close this window until typing is finished")

# Print Press Esc to cancel
print("Press Esc to stop automatic typing")

# Open and read the CSV file with explicit encoding
with open(csv_file, 'r', encoding='utf-8-sig') as file:
    reader = csv.reader(file)
    for row in reader:
        if len(row) < 3:
            print("Skipping row: Not enough columns")
            continue
        
        # Read columns
        first_column = row[0].strip()
        second_column = row[1].strip()
        third_column = row[2].strip()
        
        # Build the text to type with conditional spaces
        parts = [first_column]
        if second_column:
            parts.append(second_column)
        if third_column:
            parts.append(third_column)
        
        text_to_type = ''.join(parts)
        
        # Check if the Escape key is pressed
        if escape_pressed:
            print("Escape key pressed. Exiting...")
            break
        
        # Type the line of text using the keyboard library
        keyboard.write(text_to_type)

        # Press the Down key to simulate typing
        keyboard.press_and_release('down')

        # Delay for a short interval between each line
        # time.sleep(2)

# Stop the keyboard listener
listener.stop()
# Out:
# Don't close this window until typing is finished
# Press Esc to stop automatic typing

# %%
# v4 DOWN

import time
import csv
import keyboard  # Importing keyboard library
from pynput import keyboard as kb_listener

# CSV file to read
csv_file = 'C:/Users/JoelTencer/Documents/autotype_down.csv'

# Global variable to track if the Escape key is pressed
escape_pressed = False

# Define listener to terminate script on Escape key press
def on_press(key):
    global escape_pressed
    if key == kb_listener.Key.esc:
        escape_pressed = True
        return False  # Stop the listener

# Start the keyboard listener
listener = kb_listener.Listener(on_press=on_press)
listener.start()

# Delay for a ten seconds to switch to the desired window
time.sleep(10)

# Print don't close Window
print("Don't close this window until typing is finished")

# Print Press Esc to cancel
print("Press Esc to stop automatic typing")

# Open and read the CSV file with explicit encoding
with open(csv_file, 'r', encoding='utf-8-sig') as file:
    reader = csv.reader(file)
    for row in reader:
        if len(row) < 3:
            print("Skipping row: Not enough columns")
            continue
        
        # Read columns
        first_column = row[0].strip()
        second_column = row[1].strip()
        third_column = row[2].strip()
        
        # Build the text to type with conditional spaces
        text_to_type = first_column
        if second_column:
            text_to_type += f" {second_column}"
        if third_column:
            text_to_type += f" {third_column}"
        
        # Check if the Escape key is pressed
        if escape_pressed:
            print("Escape key pressed. Exiting...")
            break
        
        # Type the line of text using the keyboard library
        keyboard.write(text_to_type)

        # Press the Down key to simulate typing
        keyboard.press_and_release('down')

        # Delay for a short interval between each line
        # time.sleep(2)

# Stop the keyboard listener
listener.stop()
# Out:
# Don't close this window until typing is finished
# Press Esc to stop automatic typing

# %%
# v3 DOWN
# Fixed csv byte issue

import time
import csv
import keyboard  # Importing keyboard library
from pynput import keyboard as kb_listener

# CSV file to read
csv_file = 'C:/Users/JoelTencer/Documents/autotype_down.csv'

# Global variable to track if the Escape key is pressed
escape_pressed = False

# Define listener to terminate script on Escape key press
def on_press(key):
    global escape_pressed
    if key == kb_listener.Key.esc:
        escape_pressed = True
        return False  # Stop the listener

# Start the keyboard listener
listener = kb_listener.Listener(on_press=on_press)
listener.start()

# Delay for a few seconds to switch to the desired window
time.sleep(10)

# Print don't close Window
print("Don't close this window until typing is finished")

# Print Press Esc to cancel
print("Press Esc to stop automatic typing")

# Open and read the CSV file with explicit encoding
with open(csv_file, 'r', encoding='utf-8-sig') as file:
    reader = csv.reader(file)
    for row in reader:
        if len(row) < 3:
            print("Skipping row: Not enough columns")
            continue
        
        # Read columns
        prefix = row[0].strip()
        second_column = row[1].strip()
        third_column = row[2].strip()
        
        # Concatenate text
        text_to_type = f"{prefix} {second_column} {third_column}"
        
        # Check if the Escape key is pressed
        if escape_pressed:
            print("Escape key pressed. Exiting...")
            break
        
        # Type the line of text using the keyboard library
        keyboard.write(text_to_type)

        # Press the Down key to simulate typing
        keyboard.press_and_release('down')

        # Delay for a short interval between each line
        # time.sleep(2)

# Stop the keyboard listener
listener.stop()
# Out:
# Don't close this window until typing is finished
# Press Esc to stop automatic typing

# %%
# v2 from chatgpt
# Updated to use a .csv file, text1, text2, and text 3

import time
import csv
import keyboard  # Importing keyboard library
from pynput import keyboard as kb_listener

# CSV file to read
csv_file = 'C:/Users/JoelTencer/Documents/autotype_down.csv'

# Global variable to track if the Escape key is pressed
escape_pressed = False

# Define listener to terminate script on Escape key press
def on_press(key):
    global escape_pressed
    if key == kb_listener.Key.esc:
        escape_pressed = True
        return False  # Stop the listener

# Start the keyboard listener
listener = kb_listener.Listener(on_press=on_press)
listener.start()

# Delay for a few seconds to switch to the desired window
time.sleep(10)

# Print don't close Window
print("Don't close this window until typing is finished")

# Print Press Esc to cancel
print("Press Esc to stop automatic typing")

# Open and read the CSV file
with open(csv_file, 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        if len(row) < 3:
            print("Skipping row: Not enough columns")
            continue
        
        # Read columns
        first_column = row[0].strip()
        second_column = row[1].strip()
        third_column = row[2].strip()
        
        # Concatenate text
        text_to_type = f"{first_column} {second_column} {third_column}"
        
        # Check if the Escape key is pressed
        if escape_pressed:
            print("Escape key pressed. Exiting...")
            break
        
        # Type the line of text using the keyboard library
        keyboard.write(text_to_type)

        # Press the Down key to simulate typing
        keyboard.press_and_release('down')

        # Delay for a short interval between each line
        # time.sleep(2)

# Stop the keyboard listener
listener.stop()
# Out:
# Don't close this window until typing is finished
# Press Esc to stop automatic typing

# %%
# Removed autogui library and replaced with pynput keyboard
# pip install keyboard
import time
import keyboard  # Importing keyboard library
from pynput import keyboard as kb_listener

# Text file to read
text_file = 'C:/Users/JoelTencer/Documents/autotype_down.txt'

# Global variable to track if the Escape key is pressed
escape_pressed = False

# Define listener to terminate script on Escape key press
def on_press(key):
    global escape_pressed
    if key == kb_listener.Key.esc:
        escape_pressed = True
        return False  # Stop the listener

# Start the keyboard listener
listener = kb_listener.Listener(on_press=on_press)
listener.start()

# Delay for a few seconds to switch to the desired window
time.sleep(6)

# Print don't close Window
print("Don't close this window until typing is finished")

# Print Press Esc to cancel
print("Press Esc to stop automatic typing")

# Open and read the text file
with open(text_file, 'r') as file:
    # Iterate over each line in the file
    for line in file:
        # Remove any leading or trailing whitespace
        line = line.strip()

        # Check if the Escape key is pressed
        if escape_pressed:
            print("Escape key pressed. Exiting...")
            break

        # Type the line of text using the keyboard library
        keyboard.write(line)

        # Press the Down key to simulate typing
        keyboard.press_and_release('down')

        # Delay for a short interval between each line
        # time.sleep(2)

# Stop the keyboard listener
listener.stop()
# Out:
# Don't close this window until typing is finished
# Press Esc to stop automatic typing

# %%
# -*- coding: utf-8 -*-

import time
import pyautogui
from pynput import keyboard

# Text file to read
text_file = 'C:/Users/JoelTencer/Documents/autotype_HPLC.txt'

# Global variable to track if the Escape key is pressed
escape_pressed = False

# Define listener to terminate script on Escape key press
def on_press(key):
    global escape_pressed
    if key == keyboard.Key.esc:
        escape_pressed = True
        return False  # Stop the listener

# Start the keyboard listener
listener = keyboard.Listener(on_press=on_press)
listener.start()

# Delay for a few seconds to switch to the desired window
time.sleep(6)

# Print don't close Window
print("Don't close this window until typing is finished")

# Print Press Esc to cancel
print("Press Esc to stop automatic typing")

# Open and read the text file
with open(text_file, 'r') as file:
    # Iterate over each line in the file
    for line in file:
        # Remove any leading or trailing whitespace
        line = line.strip()

        # Check if the Escape key is pressed
        if escape_pressed:
            print("Escape key pressed. Exiting...")
            break

        # Type the line of text
        pyautogui.write(line)

        # Press the Down key to simulate typing
        pyautogui.press('down')

        # Delay for a short interval between each line
        # time.sleep(0.5)

# Stop the keyboard listener
listener.stop()
# Out:
# Don't close this window until typing is finished
# Press Esc to stop automatic typing

# %%
#738_SEQ1_B: 2A1m1m1m1m2 hole
#739_SEQ1_A: 2A1m1m1m1m2 knob
#740_SEQ3_B: 2A1m1m1m1m2 hole
#741_SEQ4_A: 2A1m1m1m1m2 knob
#742_SEQ5_A: 2A1m1m1m1m2 knob
#743_SEQ6_B: 2A1m1m1m1m2 hole charge
#750_SEQ1: Hz_1C10_M1M1M1M1_2A1m1m1m1m2_Fc-YTE
#751_SEQ2: Hz_1C10_M1M1M1M1_Fc-YTE_2A1m1m1m1m2_L11V
#752_SEQ5: Hz_1C10_M1M1M1M1_2A1m1m1m2m1_Fc-YTE
#753_SEQ6: Hz_1C10_M1M1M1M1_Fc-YTE_2A1m1m1m2m1_L11V
#754_SEQ1_A: Hz_1C10_M1M1M1M1_Fc-YTE knob
#755_SEQ2_B: Hz_1C10_M1M1M1M1_Fc-YTE hole
#756_SEQ3_A: Hz_1C10_M1M1M1M1_Fc-YTE knob
#757_SEQ4_B: Hz_1C10_M1M1M1M1_Fc-YTE hole
#758_SEQ5_B: Hz_1C10_M1M1M1M1_Fc-YTE hole
#759_SEQ6_A: Hz_1C10_M1M1M1M1_Fc-YTE knob-charge
#765_SEQ3: 2A1m1m1m1m2_Hz_1C10_M1M1M1M1_Fc-YTE
#766_SEQ4: 2A1m1m1m1m2_Fc-YTE_Hz_1C10_M1M1M1M1_L11V
#767_SEQ7: 2A1m1m1m2m1_Hz_1C10_M1M1M1M1_Fc-YTE
#768_SEQ8: 2A1m1m1m2m1_Fc-YTE_Hz_1C10_M1M1M1M1_L11V

# %%
# -*- coding: utf-8 -*-

import time
import pyautogui
from pynput import keyboard

#Text file to read
text_file = 'C:/Users/JoelTencer/Documents/autotype_HPLC.txt'


# Define listener to terminate script on Escape key press
# Global variable to track if the Escape key is pressed
escape_pressed = False

def on_press(key):
    global escape_pressed
    if key == keyboard.Key.esc:
        escape_pressed = True
        return False  # Stop the listener
    
#define on release, is this necessary?
def on_release(key):
    print('{0} released'.format(
        key))
    if key == keyboard.Key.esc:
        # Stop listener
        return False
    
def type_text_from_file(file_path):
    with open(file_path, 'r') as file:
        # Delay for a few seconds to switch to the desired window
        time.sleep(6)

        # Start the keyboard listener
        listener = keyboard.Listener(on_press=on_press)
        listener.start()

        # Iterate over each line in the file
        for line in file:
            # Remove any leading or trailing whitespace
            line = line.strip()

            # Check if the Escape key is pressed
            if escape_pressed:
                print("Escape key pressed. Exiting...")
                break

            # Type the line of text
            pyautogui.write(line)
            
            # Press the Down key to simulate typing
            pyautogui.press('down')

            # Delay for a short interval between each line
            # time.sleep(0.5)

        # Stop the keyboard listener
        listener.stop()

# Print don't close Window
print("Don't close this window until typing is finished")

# Print Press Esc to cancel
print("Press Esc to stop automatic typing")

# Example usage
type_text_from_file(text_file)
# Out:
# Don't close this window until typing is finished
# Press Esc to stop automatic typing
# Escape key pressed. Exiting...

# %%
#738_SEQ1_B: 2A1m1m1m1m2 hole
#739_SEQ1_A: 2A1m1m1m1m2 knob
#740_SEQ3_B: 2A1m1m1m1m2 hole
#741_SEQ4_A: 2A1m1m1m1m2 knob
#742_SEQ5_A: 2A1m1m1m1m2 knob
#743_SEQ6_B: 2A1m1m1m1m2 hole charge
#750_SEQ1: Hz_1C10_M1M1M1M1_2A1m1m1m1m2_Fc-YTE
#751_SEQ2: Hz_1C10_M1M1M1M1_Fc-YTE_2A1m1m1m1m2_L11V
#752_SEQ5: Hz_1C10_M1M1M1M1_2A1m1m1m2m1_Fc-YTE
#753_SEQ6: Hz_1C10_M1M1M1M1_Fc-YTE_2A1m1m1m2m1_L11V
#754_SEQ1_A: Hz_1C10_M1M1M1M1_Fc-YTE knob
#755_SEQ2_B: Hz_1C10_M1M1M1M1_Fc-YTE hole
#756_SEQ3_A: Hz_1C10_M1M1M1M1_Fc-YTE knob
#757_SEQ4_B: Hz_1C10_M1M1M1M1_Fc-YTE hole
#758_SEQ5_B: Hz_1C10_M1M1M1M1_Fc-YTE hole
#759_SEQ6_A: Hz_1C10_M1M1M1M1_Fc-YTE knob-charge
#765_SEQ3: 2A1m1m1m1m2_Hz_1C10_M1M1M1M1_Fc-YTE
#766_SEQ4:
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 16
#      13 escape_pressed = False
#      15 global escape_pressed
# ---> 16 if key == keyboard.Key.esc:
#      17     escape_pressed = True
#      20 with open(file_path, 'r') as file:
#      21     # Delay for a few seconds to switch to the desired window
#
# NameError: name 'key' is not defined

# %%
# autotyper runs for 7 lines then command prompt closes and it gets hung for a bit then goes nuts and types everything
# Works fine in jupyter notebook
# only messed up in command prompt run

# -*- coding: utf-8 -*-

import time
import pyautogui
from pynput import keyboard


#Text file to read
text_file = 'C:/Users/JoelTencer/Documents/autotype_HPLC.txt'


# Define listener to terminate script on Escape key press
# Global variable to track if the Escape key is pressed
escape_pressed = False

def on_press(key):
    global escape_pressed
    if key == keyboard.Key.esc:
        escape_pressed = True
        return False  # Stop the listener
    
#define on release, is this necessary?
def on_release(key):
    print('{0} released'.format(
        key))
    if key == keyboard.Key.esc:
        # Stop listener
        return False
    
def type_text_from_file(file_path):
    with open(file_path, 'r') as file:
        # Delay for a few seconds to switch to the desired window
        time.sleep(6)

        # Start the keyboard listener
        listener = keyboard.Listener(on_press=on_press)
        listener.start()

        # Iterate over each line in the file
        for line in file:
            # Remove any leading or trailing whitespace
            line = line.strip()

            # Check if the Escape key is pressed
            if escape_pressed:
                print("Escape key pressed. Exiting...")
                break

            # Before PyAutoGUI operation
            start_time = time.time()

            # Type the line of text
            pyautogui.write(line)
            
            # Press the Down key to simulate typing
            pyautogui.press('down')

            # After PyAutoGUI operation
            end_time = time.time()

            # Calculate time taken
            operation_time = end_time - start_time
            print("Time taken for PyAutoGUI operation:", operation_time)

            # Delay for a short interval between each line
            # time.sleep(0.5)

        # Stop the keyboard listener
        listener.stop()

# Print don't close Window
print("Don't close this window until typing is finished")

# Print Press Esc to cancel
print("Press Esc to stop automatic typing")

# Example usage
type_text_from_file(text_file)
# Out:
# Don't close this window until typing is finished
# Press Esc to stop automatic typing
# Time taken for PyAutoGUI operation: 0.3006739616394043
# Time taken for PyAutoGUI operation: 0.3345980644226074
# Time taken for PyAutoGUI operation: 0.2932436466217041
# Time taken for PyAutoGUI operation: 0.27198123931884766
# Time taken for PyAutoGUI operation: 0.27759695053100586
# Time taken for PyAutoGUI operation: 0.33283495903015137
# Time taken for PyAutoGUI operation: 0.34204936027526855
# Time taken for PyAutoGUI operation: 0.38050341606140137
# Time taken for PyAutoGUI operation: 0.3476569652557373
# Time taken for PyAutoGUI operation: 0.5006294250488281
# Time taken for PyAutoGUI operation: 0.33646297454833984
# Time taken for PyAutoGUI operation: 0.38217854499816895
# Time taken for PyAutoGUI operation: 0.3584268093109131
# Time taken for PyAutoGUI operation: 0.33628392219543457
# Time taken for PyAutoGUI operation: 0.32967519760131836
# Time taken for PyAutoGUI operation: 0.32702136039733887
# Time taken for PyAutoGUI operation: 0.3157055377960205
# Time taken for PyAutoGUI operation: 0.32671070098876953
# Time taken for PyAutoGUI operation: 0.31552743911743164
# Time taken for PyAutoGUI operation: 0.33463048934936523

# %%
#738_SEQ1_B: 2A1m1m1m1m2 hole
#739_SEQ1_A: 2A1m1m1m1m2 knob
#740_SEQ3_B: 2A1m1m1m1m2 hole
#741_SEQ4_A: 2A1m1m1m1m2 knob
#742_SEQ5_A: 2A1m1m1m1m2 knob
#743_SEQ6_B: 2A1m1m1m1m2 hole charge
#750_SEQ1: Hz_1C10_M1M1M1M1_2A1m1m1m1m2_Fc-YTE
#751_SEQ2: Hz_1C10_M1M1M1M1_Fc-YTE_2A1m1m1m1m2_L11V
#752_SEQ5: Hz_1C10_M1M1M1M1_2A1m1m1m2m1_Fc-YTE
#753_SEQ6: Hz_1C10_M1M1M1M1_Fc-YTE_2A1m1m1m2m1_L11V
#754_SEQ1_A: Hz_1C10_M1M1M1M1_Fc-YTE knob
#755_SEQ2_B: Hz_1C10_M1M1M1M1_Fc-YTE hole
#756_SEQ3_A: Hz_1C10_M1M1M1M1_Fc-YTE knob
#757_SEQ4_B: Hz_1C10_M1M1M1M1_Fc-YTE hole
#758_SEQ5_B: Hz_1C10_M1M1M1M1_Fc-YTE hole
#759_SEQ6_A: Hz_1C10_M1M1M1M1_Fc-YTE knob-charge
#765_SEQ3: 2A1m1m1m1m2_Hz_1C10_M1M1M1M1_Fc-YTE
#766_SEQ4: 2A1m1m1m1m2_Fc-YTE_Hz_1C10_M1M1M1M1_L11V
#767_SEQ7: 2A1m1m1m2m1_Hz_1C10_M1M1M1M1_Fc-YTE
#768_SEQ8: 2A1m1m1m2m1_Fc-YTE_Hz_1C10_M1M1M1M1_L11V
